# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("..")
from IPython.display import display, HTML, clear_output, IFrame, Javascript
from pprint import pprint
from sklearn.datasets import load_boston
import pandas as pd
import panel as pn
pn.extension()

from campbell.simple_scatter import SimpleScatter


bos = load_boston()
df = pd.DataFrame(bos.data, columns=bos.feature_names)
df = df.iloc[:20, :]

fig = SimpleScatter(df=df, jupyter=True)
HTML(fig.plot())

# %%
fig = SimpleScatter(df=df, jupyter=True)
fig.plot()
# Out:
# '<!--\n<!DOCTYPE html>\n<html lang="en">\n<head>\n    <meta charset="UTF-8">\n    <title>Simple scatter plot</title>\n    <style>\n        #chart{\n          margin: 4px;\n          box-shadow: 0px 0px 4px lightgray;\n          background-color: white;\n          border-radius: 10px;\n        }\n        .tooltip {\n        position: absolute;\n        text-align: center;\n        width: auto;\n        height: auto;\n        padding: 5px;\n        font-size: 10px;\n        background: white;\n        box-shadow: 0px 0px 10px lightgray;\n        visibility: hidden;}\n    </style>\n</head>\n-->\n<!--<body>-->\n<style>\n    #chart{\n      margin: 4px;\n      box-shadow: 0px 0px 4px lightgray;\n      background-color: white;\n      border-radius: 10px;\n    }\n    .tooltip {\n    position: absolute;\n    text-align: center;\n    width: auto;\n    height: auto;\n    padding: 5px;\n    font-size: 10px;\n    background: white;\n    box-shadow: 0px 0px 10px lightgray;\n    visibility: hidden;
# ...

# %%
import sys
sys.path.append("..")
from IPython.core.display import display, HTML

from campbell.test import TestD3

# %%
display(HTML('<script src="https://d3js.org/d3.v5.min.js" charset="utf-8" ></script><script>alert("load D3");</script>'))
# Out:
# <script src="https://d3js.org/d3.v3.min.js" charset="utf-8" ></script><script>alert("load D3");</script>

# %%
d3_download = """ <script src="https://d3js.org/d3.v4.min.js" charset="utf-8" > </script>"""
HTML(d3_download)
# Out:
#  <script src="https://d3js.org/d3.v4.min.js" charset="utf-8" > </script>

# %%
HTML(TestD3())
# Out:
#  <script src="http://d3js.org/d3.v5.min.js" charset="utf-8" > </script>
#     <style >
#     .axis path,
#     .axis line {
#       fill: none;
#       stroke: #000;
#       shape-rendering: crispEdges;
#     }
#
#     .dot {
#       stroke: #000;
#     }
#      </style>
#     <div id="graph-div"></div>
#     <script >
#
#     var margin = {top: 20, right: 20, bottom: 30, left: 40},
#     // ****    width = 960 - margin.left - margin.right, ****
#     // ****    height = 500 - margin.top - margin.bottom; ****
#         width = 720 - margin.left - margin.right,
#         height = 375 - margin.top - margin.bottom;
#
#     var x = d3.scale.linear()
#         .range([0, width]);
#
#     var y = d3.scale.linear()
#         .range([height, 0]);
#
#     var color = d3.scale.category10();
#
#     var xAxis = d3.svg.axis()
#         .scale(x)
#         .orient("bottom");
#
#     var yAxis = d3.svg.axis()
#         .scale(y)
#         .orient("left");
#
# ...

# %%
from pprint import pprint
pprint(fig.plot())
# Out:
# ('<!--\n'
#  '<!DOCTYPE html>\n'
#  '<html lang="en">\n'
#  '<head>\n'
#  '    <meta charset="UTF-8">\n'
#  '    <title>Simple scatter plot</title>\n'
#  '    <style>\n'
#  '        #chart{\n'
#  '          margin: 4px;\n'
#  '          box-shadow: 0px 0px 4px lightgray;\n'
#  '          background-color: white;\n'
#  '          border-radius: 10px;\n'
#  '        }\n'
#  '        .tooltip {\n'
#  '        position: absolute;\n'
#  '        text-align: center;\n'
#  '        width: auto;\n'
#  '        height: auto;\n'
#  '        padding: 5px;\n'
#  '        font-size: 10px;\n'
#  '        background: white;\n'
#  '        box-shadow: 0px 0px 10px lightgray;\n'
#  '        visibility: hidden;}\n'
#  '    </style>\n'
#  '</head>\n'
#  '-->\n'
#  '<body>\n'
#  '    <!--\n'
#  '    <style>\n'
#  '        #chart{\n'
#  '          margin: 4px;\n'
#  '          box-shadow: 0px 0px 4px lightgray;\n'
#  '          background-color: white;\n'
#  '          border-radius: 10px;\n'
# ...
